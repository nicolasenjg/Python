# %% [markdown]
# # 6.2 Exploring Relationships

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import os

# %%
# Create Path

path=r'C:\Users\Nico\Desktop\Curso Data Analytics\Module 6\World Happiness report'

# %%
#Load happy_df_2023 dataset and create a dataframe called 'happy_df_2023'

happy_df_2023 = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'happy_df_2023.csv'))

# %% [markdown]
# ## Correlations

# %%
# Create a correlation matrix using pandas

happy_df_2023.corr()
# Out:
# C:\Users\Nico\AppData\Local\Temp\ipykernel_28920\2281253161.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   happy_df_2023.corr()
#                               Unnamed: 0  happiness_score  gdp_per_capita  \
# Unnamed: 0                      1.000000        -0.975792       -0.812466
# happiness_score                -0.975792         1.000000        0.784367
# gdp_per_capita                 -0.812466         0.784367        1.000000
# social_support                 -0.813851         0.834532        0.738069
# healthy_life_expectancy        -0.763523         0.746928        0.837533
# freedom_to_make_life_choices   -0.624836         0.662924        0.451439
# generosity                     -0.017894         0.044082       -0.156456
# perceptions_of_corruption       0.483251        -0.471911       -0.436961
# ...

# %%
matplotlib.__version__
# Out:
# '3.7.1'

# %%
happy_df_2023 = happy_df_2023.drop(columns = ['Unnamed: 0'])

# %%
Happy_df= happy_df_2023.drop(columns = ['rank'])

# %%
Happy_df.corr()
# Out:
# C:\Users\Nico\AppData\Local\Temp\ipykernel_28920\3029739333.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Happy_df.corr()
#                               happiness_score  gdp_per_capita  social_support  \
# happiness_score                      1.000000        0.784367        0.834532
# gdp_per_capita                       0.784367        1.000000        0.738069
# social_support                       0.834532        0.738069        1.000000
# healthy_life_expectancy              0.746928        0.837533        0.725524
# freedom_to_make_life_choices         0.662924        0.451439        0.541630
# generosity                           0.044082       -0.156456        0.036574
# perceptions_of_corruption           -0.471911       -0.436961       -0.272490
#
# ...

# %%
# Create a correlation heatmap using matplotlib

plt.matshow(happy_df_2023.corr())
plt.show()
# Out:
# C:\Users\Nico\AppData\Local\Temp\ipykernel_28920\763215029.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.matshow(happy_df_2023.corr())

# %%
# Save figure
plt.matshow(happy_df_2023.corr())
plt.savefig("out.png")
# Out:
# C:\Users\Nico\AppData\Local\Temp\ipykernel_28920\2312066850.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.matshow(happy_df_2023.corr())

# %%
#current dir
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\Nico\\World Happiness Report\\03 Scripts'

# %%
# Add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(8,8)) # figure size 
plt.matshow(happy_df_2023.corr(), fignum=f.number) # type of plot
plt.xticks(range(happy_df_2023.shape[1]), happy_df_2023.columns, fontsize=10, rotation=45) # x axis labels
plt.yticks(range(happy_df_2023.shape[1]), happy_df_2023.columns, fontsize=10) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# C:\Users\Nico\AppData\Local\Temp\ipykernel_28920\2863392271.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.matshow(happy_df_2023.corr(), fignum=f.number) # type of plot
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(happy_df_2023.corr(), annot = True, ax = ax) # The `annot` argument allows the plot to 
#place the correlation coefficients onto the heatmap.
# Out:
# C:\Users\Nico\AppData\Local\Temp\ipykernel_28920\315306814.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = sns.heatmap(happy_df_2023.corr(), annot = True, ax = ax) # The `annot` argument allows the plot to

# %% [markdown]
# ##  Scatterplots

# %%
# Create a scatterplot for the "happiness_score" and "gdp_per_capita" columns in seaborn

sns.lmplot(x = 'happiness_score', y = 'gdp_per_capita', data = happy_df_2023)

# %%
# Create a scatterplot for the "healthy_life_expectancy" and "gdp_per_capita" columns in seaborn

sns.lmplot(x = 'healthy_life_expectancy', y = 'gdp_per_capita', data = happy_df_2023)

# %%
# Create a pair plot 

g = sns.pairplot(happy_df_2023)

# %%
sub= happy_df_2023[['happiness_score','gdp_per_capita','social_support']]

# %%
g2 = sns.pairplot(sub)

# %% [markdown]
# ## Categorical Plots

# %%
sns.histplot(happy_df_2023['happiness_score'], bins = np.arange(0,10,0.5), kde=True)
plt.ylabel("Number of Countries")
# Out:
# Text(0, 0.5, 'Number of Countries')

# %% [markdown]
# ### Questions

# %% [markdown]
# ## Are there countries with low healthy life expectancy but high happiness scores?
#
# Based on the inforamtion gatheres we could no see countries that have both variables high, the correlation is strong. There are no outliers where we can see this. We can infer that higher healthy life expectancy higer Happiness Score.

# %% [markdown]
# ## How does generosity correlate with other variables like GDP per capita or social support?
#
# This is a variable which does not have a strong influence withing happiness score. We can even see countries that have low level of generosity and have a higer score of happiness

# %% [markdown]
# ## Are there countries where happiness remains high despite high levels of perceived corruption?
#
# Yes with the Sacterplot graph we can see that actually that a lot of countries that have a higer level of perceived corruption keep their leves of happines high.
