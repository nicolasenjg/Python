# %% [markdown]
# # 4.7 Deriving New Variables NJ

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
path=r'C:\Users\Nico\Desktop\Curso Data Analytics\Module 4\Instacart Basket Analysis'

# %%
orders_products_merged = pd.read_pickle(os.path.join(path,'02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path,'02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 15)

# %%
#define function- to sort values

def price_label(row):
    if row['prices'] <= 5:
        return 'Low-range product'
    elif (row['prices'] >5) and (row['prices'] <= 15):
        return 'Mid-range product'
    elif row['prices'] > 15:
        return 'High-range product'
    else: return 'Not enough data'

# %%
# apply function just created

df['price_range'] = df.apply(price_label,axis=1)
# Out:
# C:\Users\Nico\AppData\Local\Temp\ipykernel_34428\1402325726.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label,axis=1)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge        price_range
# ...

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
df['price_range'].value_counts ()
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %%
ords_prods_merge['prices'].max()
# Out:
# 99999.0

# %% [markdown]
#  ### If statement with the loc() Function

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] < 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    200945
# NaN                   42605
# Name: price_range_loc, dtype: int64

# %%
# use it in the whole data frame

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] < 5, 'price_range_loc'] = 'Low-range product'

# %%
ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21860860
# Low-range product      9900417
# High-range product      417678
# NaN                     225904
# Name: price_range_loc, dtype: int64

# %% [markdown]
# ### If-Statements with For-Loops

# %%
# What day is the most popular to order
ords_prods_merge['order_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: order_day_of_week, dtype: int64

# %%
#create loop
result = []
for value in ords_prods_merge [ 'order_day_of_week']:
    if value == 0:
        result.append('Busiest Day')
    elif value == 4:
        result.append('Least busy')
    else:
        result.append('Regular busy')

# %%
result
# Out:
# ['Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Least busy',
#  'Least busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Least busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Least busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Least busy',
#  'Least busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Least busy',
#  'Regular busy',
#  'Busiest Day',
# ...

# %%
#Merged column in the data set
ords_prods_merge['busiest_day'] = result

# %%
ords_prods_merge['busiest_day'].value_counts(dropna=False)
# Out:
# Regular busy    22416875
# Busiest Day      6204182
# Least busy       3783802
# Name: busiest_day, dtype: int64

# %% [markdown]
# # Tasks

# %%
# Create a new column Named "Busiests days" considering the 2 busiest days of the week and 2 slowest days of the week

# %%
#create loop
resultA = []
for value in ords_prods_merge [ 'order_day_of_week']:
    if value == 0:
        resultA.append('Busiest day')
    elif value == 1:
        resultA.append('Busiest day')
    elif value == 4:
        resultA.append('Slowest day')
    elif value == 3:
        resultA.append('Slowest day')
    else:
        resultA.append('Regular busy')

# %%
resultA
# Out:
# ['Regular busy',
#  'Slowest day',
#  'Slowest day',
#  'Slowest day',
#  'Slowest day',
#  'Regular busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Slowest day',
#  'Busiest day',
#  'Regular busy',
#  'Regular busy',
#  'Busiest day',
#  'Busiest day',
#  'Regular busy',
#  'Regular busy',
#  'Slowest day',
#  'Slowest day',
#  'Slowest day',
#  'Slowest day',
#  'Slowest day',
#  'Slowest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Regular busy',
#  'Regular busy',
#  'Busiest day',
#  'Regular busy',
#  'Regular busy',
#  'Busiest day',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Slowest day',
#  'Regular busy',
#  'Slowest day',
#  'Busiest day',
#  'Busiest day',
#  'Regular busy',
#  'Slowest day',
#  'Slowest day',
#  'Regular busy',
#  'Regular busy',
#  'Busiest day',
#  'Busiest day',
#  'Regular busy',
#  'Busiest day',
#  'Busiest day',
#  'Slowest day',
#  'Regular busy',
#  'Busiest day',
#  'Busiest day',
# ...

# %%
#Merged Column in the DataSet
ords_prods_merge['Busiest Days'] = resultA

# %%
ords_prods_merge['Busiest Days'] . value_counts(dropna = False)
# Out:
# Regular busy    12916111
# Busiest day     11864412
# Slowest day      7624336
# Name: Busiest Days, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %%
# Identify first what are the most busiest hours
ords_prods_merge['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %%
# Define loop to create a new colum
Busy = []
for value in ords_prods_merge['order_hour_of_day']:
    if value == 10:
        Busy.append('Most orders')
    elif value == 11:
        Busy.append('Most orders')
    elif value == 14:
        Busy.append('Most orders')
    elif value == 15:
        Busy.append('Most orders')
    elif value == 13:
        Busy.append('Most orders')
    elif value == 12:
        Busy.append('Most orders')
    elif value == 16:
        Busy.append('Most orders')
    elif value == 9:
        Busy.append('Most orders')
    elif value == 17:
        Busy.append('Average orders')
    elif value == 8:
        Busy.append('Average orders')
    elif value == 18:
        Busy.append('Average orders')
    elif value == 19:
        Busy.append('Average orders')
    elif value == 20:
        Busy.append('Average orders')
    elif value == 7:
        Busy.append('Average orders')
    elif value == 21:
        Busy.append('Average orders')
    elif value == 23:
        Busy.append('Average orders')
    else: 
        Busy.append('Fewest orders')

# %%
Busy
# Out:
# ['Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
# ...

# %%
ords_prods_merge['busiest_period_of_day'] = Busy

# %%
ords_prods_merge['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       21118071
# Average orders     9765742
# Fewest orders      1521046
# Name: busiest_period_of_day, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %%
#Export df_merged as pickle file due to size
orders_products_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
